# %% [markdown]
# # Match hospitals to LSOAs
#
# Find which LSOA contains each hospital.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# For importing geojson:
import json

# For creating new points:
# from geojson import Feature, Point #FeatureCollection
from shapely.geometry import shape, Point

# %% [markdown]
# ## Import data

# %% [markdown]
# ### Hospital locations

# %%
df_hospitals = pd.read_csv('../data/stroke_hospitals_2022.csv')

df_hospitals.head()
# Out:
#   Postcode Hospital_name  Use_IVT  Use_MT  Use_MSU  Country  \
# 0   RM70AG        RM70AG        1       1        1  England
# 1    E11BB         E11BB        1       1        1  England
# 2   SW66SX        SW66SX        1       1        1  England
# 3   SE59RW        SE59RW        1       1        1  England
# 4   BR68ND        BR68ND        1       0        0  England
#
#   Strategic Clinical Network                          Health Board / Trust  \
# 0                 London SCN                                       Barking
# 1                 London SCN                        Barts Health NHS Trust
# 2                 London SCN         Imperial College Healthcare NHS Trust
# 3                 London SCN  King's College Hospital NHS Foundation Trust
# 4                 London SCN  King's College Hospital NHS Foundation Trust
#
#                                          Stroke Team  \
# 0   Havering and Redbridge University Hospitals N...
# 1                          The Royal London Hospital
# 2                     Charing Cross Hospital, London
# 3                    King's College Hospital, London
# 4                 Princess Royal University Hospital
#
#                                 SSNAP name  ...  Thrombolysis  ivt_rate  \
# 0             Queens Hospital Romford HASU  ...           117      11.9
# 1               Royal London Hospital HASU  ...           115      13.4
# 2              Charing Cross Hospital HASU  ...           113       9.9
# 3             King's College Hospital HASU  ...           124      15.0
# 4  Princess Royal University Hospital HASU  ...           113      13.3
#
#    Easting  Northing      long        lat  Neuroscience  \
# 0   551118    187780  0.179031  51.568647             1
# 1   534829    181798 -0.058133  51.519018             1
# 2   524226    176487 -0.212736  51.473717             1
# 3   532536    176228 -0.093251  51.469505             1
# 4   543443    165032  0.059146  51.366243             0
#
#    30 England Thrombectomy Example   hospital_city Notes
# 0                                0         Romford   NaN
# 1                                1    Royal London   NaN
# 2                                1   Charing Cross   NaN
# 3                                0   Kings College   NaN
# 4                                0  Princess Royal   NaN
#
# [5 rows x 21 columns]

# %%
hospital_points = []

for r in range(df_hospitals.shape[0]):
    # Get longitude and latitude from the dataframe
    # and convert it into a "Point" that the shape package can understand
    # and later compare with polygons of LSOA coordinates.
    long = df_hospitals['long'].iloc[r]
    lat = df_hospitals['lat'].iloc[r]
    point = Point(long, lat)

    hospital_points.append(point)

# %%
hospital_points
# Out:
# [<POINT (0.179 51.569)>,
#  <POINT (-0.058 51.519)>,
#  <POINT (-0.213 51.474)>,
#  <POINT (-0.093 51.47)>,
#  <POINT (0.059 51.366)>,
#  <POINT (-0.322 51.575)>,
#  <POINT (-0.176 51.427)>,
#  <POINT (-0.137 51.525)>,
#  <POINT (-1.515 52.911)>,
#  <POINT (-0.884 52.236)>,
#  <POINT (-1.186 52.943)>,
#  <POINT (-1.16 52.991)>,
#  <POINT (-1.232 53.134)>,
#  <POINT (-0.52 53.234)>,
#  <POINT (-0.01 52.991)>,
#  <POINT (-1.135 52.628)>,
#  <POINT (0.451 51.558)>,
#  <POINT (-0.472 52.128)>,
#  <POINT (0.139 52.174)>,
#  <POINT (0.899 51.91)>,
#  <POINT (-0.213 51.925)>,
#  <POINT (1.198 52.057)>,
#  <POINT (1.718 52.562)>,
#  <POINT (-0.476 51.895)>,
#  <POINT (0.466 51.775)>,
#  <POINT (1.221 52.618)>,
#  <POINT (-0.279 52.584)>,
#  <POINT (0.447 52.757)>,
#  <POINT (0.689 51.554)>,
#  <POINT (-0.404 51.649)>,
#  <POINT (0.709 52.232)>,
#  <POINT (-1.656 52.818)>,
#  <POINT (-2.119 52.503)>,
#  <POINT (-1.478 52.513)>,
#  <POINT (-1.83 52.48)>,
#  <POINT (-2.096 52.6)>,
#  <POINT (-1.988 52.527)>,
#  <POINT (-2.511 52.712)>,
#  <POINT (-1.583 52.29)>,
#  <POINT (-1.938 52.453)>,
#  <POINT (-1.438 52.421)>,
#  <POINT (-2.215 53.004)>,
#  <POINT (-1.999 52.582)>,
#  <POINT (-2.181 52.191)>,
#  <POINT (-2.706 52.057)>,
#  <POINT (-2.931 53.466)>,
#  <POINT (-2.898 53.209)>,
#  <POINT (-2.476 53.118)>,
#  <POINT (-2.965 53.41)>,
#  <POINT (-2.978 53.634)>,
#  <POINT (-2.785 53.42)>,
#  <POINT (-2.611 53.394)>,
#  <POINT (-3.096 53.37)>,
#  <POINT (-3.016 53.821)>,
#  <POINT (-2.463 53.736)>,
#  <POINT (-2.707 53.791)>,
#  <POINT (-2.255 53.601)>,
#  <POINT (-2.323 53.488)>,
#  <POINT (-2.132 53.384)>,
#  <POINT (-3.208 54.136)>,
#  <POINT (-2.799 54.043)>,
#  <POINT (-1.411 54.903)>,
#  <POINT (-1.594 54.788)>,
#  <POINT (-1.581 54.939)>,
#  <POINT (-1.619 54.98)>,
#  <POINT (-2.955 54.896)>,
#  <POINT (-3.563 54.53)>,
#  <POINT (-1.348 54.583)>,
#  <POINT (-1.569 55.074)>,
#  <POINT (-1.215 54.552)>,
#  <POINT (-1.43 54.972)>,
#  <POINT (-1.499 53.559)>,
#  <POINT (-1.795 53.806)>,
#  <POINT (-1.858 53.705)>,
#  <POINT (-1.4 53.236)>,
#  <POINT (-1.109 53.531)>,
#  <POINT (-1.518 53.994)>,
#  <POINT (-0.358 53.744)>,
#  <POINT (-1.552 53.801)>,
#  <POINT (-1.489 53.692)>,
#  <POINT (-0.668 53.588)>,
#  <POINT (-1.343 53.414)>,
#  <POINT (-1.493 53.378)>,
#  <POINT (-1.084 53.969)>,
#  <POINT (-0.527 51.378)>,
#  <POINT (-0.09 50.991)>,
#  <POINT (-0.118 50.819)>,
#  <POINT (0.259 51.435)>,
#  <POINT (1.087 51.267)>,
#  <POINT (1.389 51.378)>,
#  <POINT (0.916 51.141)>,
#  <POINT (0.271 50.787)>,
#  <POINT (-0.273 51.326)>,
#  <POINT (-0.742 51.32)>,
#  <POINT (0.484 51.274)>,
#  <POINT (0.307 51.149)>,
#  <POINT (0.542 51.38)>,
#  <POINT (-0.607 51.241)>,
#  <POINT (-0.162 51.219)>,
#  <POINT (-0.768 50.844)>,
#  <POINT (-0.363 50.817)>,
#  <POINT (-2.232 51.866)>,
#  <POINT (-1.727 51.539)>,
#  <POINT (-2.593 51.497)>,
#  <POINT (-4.05 51.092)>,
#  <POINT (-4.114 50.417)>,
#  <POINT (-5.094 50.267)>,
#  <POINT (-3.507 50.717)>,
#  <POINT (-2.391 51.392)>,
#  <POINT (-1.79 51.044)>,
#  <POINT (-3.12 51.012)>,
#  <POINT (-3.554 50.482)>,
#  <POINT (-2.595 51.459)>,
#  <POINT (-2.971 51.322)>,
#  <POINT (-2.635 50.945)>,
#  <POINT (-0.753 51.626)>,
#  <POINT (-0.574 51.532)>,
#  <POINT (-0.736 52.026)>,
#  <POINT (-1.337 52.054)>,
#  <POINT (-1.22 51.764)>,
#  <POINT (-0.959 51.451)>,
#  <POINT (-2.447 50.713)>,
#  <POINT (-1.329 51.062)>,
#  <POINT (-1.301 50.711)>,
#  <POINT (-1.973 50.722)>,
#  <POINT (-1.07 50.85)>,
#  <POINT (-1.821 50.747)>,
#  <POINT (-1.435 50.933)>,
#  <POINT (-2.996 51.646)>,
#  <POINT (-3.496 53.272)>,
#  <POINT (-3.01 53.046)>,
#  <POINT (-4.16 53.209)>,
#  <POINT (-3.189 51.507)>,
#  <POINT (-3.386 51.764)>,
#  <POINT (-3.572 51.518)>,
#  <POINT (-4.072 52.416)>,
#  <POINT (-4.136 51.692)>,
#  <POINT (-4.285 51.868)>,
#  <POINT (-4.965 51.813)>,
#  <POINT (-3.935 51.685)>,
#  <POINT (-2.998 51.58)>]

# %% [markdown]
# ### Geojson containing all LSOAs:

# %%
with open('./LSOA_2011.geojson') as f:
    geojson_ew = json.load(f)

# %%
# Fill these lists with the LSOAs containing the hospitals:
hospital_LSOA11CD = []
hospital_LSOA11NM = []
hospital_LSOA11NMW = []

for point in hospital_points:
    # Check each LSOA in turn to see if it contains this point.
    i = 0
    while i < len(geojson_ew['features']):
        # Get the coordinates and other info for this LSOA:
        feature = geojson_ew['features'][i]
        # Turn this into a shape:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            # Save LSOA details to list:
            hospital_LSOA11CD.append(feature['properties']['LSOA11CD'])
            hospital_LSOA11NM.append(feature['properties']['LSOA11NM'])
            hospital_LSOA11NMW.append(feature['properties']['LSOA11NMW'])
            # Update the iterator so that the loop breaks:
            i = len(geojson_ew['features'])
        # Update the iterator for another go round the loop:
        i += 1

# %% [markdown]
# ## Link the LSOAs with other regions
#
# Import the big file we made earlier:

# %%
df_regions = pd.read_csv('./LSOA_regions.csv')

df_regions.head()
# Out:
#     LSOA11CD   LSOA11NM    CCG19CD                      CCG19NM    STP19CD  \
# 0  E01031349  Adur 001A  E38000213  NHS Coastal West Sussex CCG  E54000033
# 1  E01031350  Adur 001B  E38000213  NHS Coastal West Sussex CCG  E54000033
# 2  E01031351  Adur 001C  E38000213  NHS Coastal West Sussex CCG  E54000033
# 3  E01031352  Adur 001D  E38000213  NHS Coastal West Sussex CCG  E54000033
# 4  E01031370  Adur 001E  E38000213  NHS Coastal West Sussex CCG  E54000033
#
#                   STP19NM LHB20CD LHB20NM LHB20NMW    LAD17CD LAD17NM  \
# 0  Sussex and East Surrey     NaN     NaN      NaN  E07000223    Adur
# 1  Sussex and East Surrey     NaN     NaN      NaN  E07000223    Adur
# 2  Sussex and East Surrey     NaN     NaN      NaN  E07000223    Adur
# 3  Sussex and East Surrey     NaN     NaN      NaN  E07000223    Adur
# 4  Sussex and East Surrey     NaN     NaN      NaN  E07000223    Adur
#
#      SCN17CD           SCN17NM    RGN11CD     RGN11NM
# 0  E55000010  South East Coast  E12000008  South East
# 1  E55000010  South East Coast  E12000008  South East
# 2  E55000010  South East Coast  E12000008  South East
# 3  E55000010  South East Coast  E12000008  South East
# 4  E55000010  South East Coast  E12000008  South East

# %%
all_regions = []

for LSOA in hospital_LSOA11CD:
    # Get region information for this hospital:
    regions_here = df_regions[df_regions['LSOA11CD'] == LSOA].values
    # Keep a copy of everything except the first two columns
    # (LSOA11 codes and names), which we already have ready:
    all_regions.append(regions_here[0][2:])

all_regions = np.array(all_regions, dtype=object)
all_regions
# Out:
# array([['E38000077', 'NHS Havering CCG', 'E54000029', ..., 'London',
#         'E12000007', 'London'],
#        ['E38000186', 'NHS Tower Hamlets CCG', 'E54000029', ..., 'London',
#         'E12000007', 'London'],
#        ['E38000070', 'NHS Hammersmith and Fulham CCG', 'E54000027', ...,
#         'London', 'E12000007', 'London'],
#        ...,
#        [nan, nan, nan, ..., nan, 'W92000004', 'Wales'],
#        [nan, nan, nan, ..., nan, 'W92000004', 'Wales'],
#        [nan, nan, nan, ..., nan, 'W92000004', 'Wales']], dtype=object)

# %% [markdown]
# ## Create a dataframe to save

# %%
# Gather the hospital names, locations, and containing LSOAs...
table = np.stack([
    df_hospitals['Postcode'],
    df_hospitals['Stroke Team'],
    df_hospitals['long'],
    df_hospitals['lat'],
    hospital_LSOA11CD,
    hospital_LSOA11NM,
    hospital_LSOA11NMW,
    ], axis=-1)

# ... and then add the other region information from the file.
table = np.concatenate([table, all_regions], axis=1)

# %%
df_hospitals_and_lsoas = pd.DataFrame(
    table,
    columns=[
        'Postcode',
        'Stroke Team',
        'long',
        'lat',
        'LSOA11CD',
        'LSOA11NM',
        'LSOA11NMW',
        *df_regions.columns[2:]
    ]
)

df_hospitals_and_lsoas.head()
# Out:
#   Postcode                                        Stroke Team      long  \
# 0   RM70AG   Havering and Redbridge University Hospitals N...  0.179031
# 1    E11BB                          The Royal London Hospital -0.058133
# 2   SW66SX                     Charing Cross Hospital, London -0.212736
# 3   SE59RW                    King's College Hospital, London -0.093251
# 4   BR68ND                 Princess Royal University Hospital  0.059146
#
#          lat   LSOA11CD                     LSOA11NM  \
# 0  51.568647  E01002248                Havering 017C
# 1  51.519018  E01004322           Tower Hamlets 017A
# 2  51.473717  E01001906  Hammersmith and Fulham 022C
# 3  51.469505  E01003076                 Lambeth 014C
# 4  51.366243  E01000751                 Bromley 036C
#
#                      LSOA11NMW    CCG19CD                         CCG19NM  \
# 0                Havering 017C  E38000077                NHS Havering CCG
# 1           Tower Hamlets 017A  E38000186           NHS Tower Hamlets CCG
# 2  Hammersmith and Fulham 022C  E38000070  NHS Hammersmith and Fulham CCG
# 3                 Lambeth 014C  E38000092                 NHS Lambeth CCG
# 4                 Bromley 036C  E38000023                 NHS Bromley CCG
#
#      STP19CD                                        STP19NM LHB20CD LHB20NM  \
# 0  E54000029        East London Health and Care Partnership     NaN     NaN
# 1  E54000029        East London Health and Care Partnership     NaN     NaN
# 2  E54000027  North West London Health and Care Partnership     NaN     NaN
# 3  E54000030                Our Healthier South East London     NaN     NaN
# 4  E54000030                Our Healthier South East London     NaN     NaN
#
#   LHB20NMW    LAD17CD                 LAD17NM    SCN17CD SCN17NM    RGN11CD  \
# 0      NaN  E09000016                Havering  E55000014  London  E12000007
# 1      NaN  E09000030           Tower Hamlets  E55000014  London  E12000007
# 2      NaN  E09000013  Hammersmith and Fulham  E55000014  London  E12000007
# 3      NaN  E09000022                 Lambeth  E55000014  London  E12000007
# 4      NaN  E09000006                 Bromley  E55000014  London  E12000007
#
#   RGN11NM
# 0  London
# 1  London
# 2  London
# 3  London
# 4  London

# %% [markdown]
# Save this dataframe to file:

# %%
df_hospitals_and_lsoas.to_csv('hospitals_and_lsoas.csv', index=False)
